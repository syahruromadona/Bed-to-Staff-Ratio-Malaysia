# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv(r"C:\Users\USER\Videos\Data Analysis Portfolio\Hospital Utilisation\national_bed_staff.csv")
df
# Out:
#    year  total_national_bed  total_national_staff  avg_national_ratio
# 0  2015               82778                132082                0.63
# 1  2016               83990                137743                0.61
# 2  2017               84324                143596                0.59
# 3  2018               84848                147674                0.57
# 4  2019               85872                154177                0.56
# 5  2020               88234                156639                0.56
# 6  2021               89698                162634                0.55
# 7  2022               90334                167690                0.54

# %%
ax = df.plot(
    title= 'Malaysia Trend for 8 Years: Bed-to-staff ratio',
    y = 'avg_national_ratio',
    x = 'year'
)

ax.set_ylim(0.48,0.64)
# Out:
# (0.48, 0.64)
